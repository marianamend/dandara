# %% [markdown]
# # Análise Exploratória dos Dados Eleitorais (05/2022)

# %% [markdown]
# ## 1. Importando os arquivos necessários

# %%
import pandas as pd
import numpy as np

# %%
data = 'dados/2022/bweb_1t_SP_051020221321/bweb_1t_SP_051020221321.csv'
locais_de_votacao = 'dados/2022/locaisdevotacao.csv'


pd.set_option('display.max_columns', None)

# %%
df_data = pd.read_csv(data, sep = ';', encoding = 'latin1')

# %%
df_locais_de_votacao = pd.read_csv(locais_de_votacao, encoding = 'latin1', on_bad_lines='skip',  
                  names=["zona_eleitoral", "escola", "endereco_escola", "cidade", "sessao", "sessao_1"])

# %%
#df2 = df[df['NM_MUNICIPIO'] == 'MAUÁ']

# %%
#df3 = df[df['SG_PARTIDO'] == 'PSOL']
#df4 = df[df['NR_VOTAVEL'] == 50000]
#df.head()
df_data
# Out:
#           DT_GERACAO HH_GERACAO  ANO_ELEICAO  CD_TIPO_ELEICAO  \
# 0         05/10/2022   16:02:45         2022                0
# 1         05/10/2022   16:02:45         2022                0
# 2         05/10/2022   16:02:45         2022                0
# 3         05/10/2022   16:02:45         2022                0
# 4         05/10/2022   16:02:45         2022                0
# ...              ...        ...          ...              ...
# 19167368  05/10/2022   16:02:45         2022                0
# 19167369  05/10/2022   16:02:45         2022                0
# 19167370  05/10/2022   16:02:45         2022                0
# 19167371  05/10/2022   16:02:45         2022                0
# 19167372  05/10/2022   16:02:45         2022                0
#
#             NM_TIPO_ELEICAO  CD_PLEITO   DT_PLEITO  NR_TURNO  CD_ELEICAO  \
# 0         Eleição Ordinária        406  02/10/2022         1         544
# ...

# %%
#df.columns

# %%
#df['NM_MUNICIPIO'].unique()

# %%
df_locais_de_votacao
# Out:
#                         zona_eleitoral  \
# 0      1a. ZE - SÃO PAULO - BELA VISTA
# 1      1a. ZE - SÃO PAULO - BELA VISTA
# 2      1a. ZE - SÃO PAULO - BELA VISTA
# 3      1a. ZE - SÃO PAULO - BELA VISTA
# 4      1a. ZE - SÃO PAULO - BELA VISTA
# ...                                ...
# 10940                427a. ZE - URÂNIA
# 10941                427a. ZE - URÂNIA
# 10942                427a. ZE - URÂNIA
# 10943                427a. ZE - URÂNIA
# 10944                427a. ZE - URÂNIA
#
#                                                   escola  \
# 0                    COLÉGIO JOÃO E RAPHAELA PASSALACQUA
# 1                                       COLÉGIO OBJETIVO
# 2                     COLÉGIO OBJETIVO - ANHEMBI MORUMBI
# 3                                  EE. CAETANO DE CAMPOS
# 4                         EE. DRA. MARIA AUGUSTA SARAIVA
# ...                                                  ...
# 10940                        EE. JOSÉ TEIXEIRA DO AMARAL
# ...

# %% [markdown]
# ## 1.1 Extraindo os valores do campo 'sessao'

# %%
df_locais_de_votacao.columns
# Out:
# Index(['1a. ZE - SÃO PAULO - BELA VISTA,"COLÉGIO JOÃO E RAPHAELA PASSALACQUA","RUA JOÃO PASSALACQUA, 207","SÃO PAULO","Da 87ª à 97ª',
#        ' 393ª', ' 410ª', ' 421ª', ' 429ª', ' 438ª', ' 460ª', ' ","87ª', ' "'],
#       dtype='object')

# %%
column_sessao = df_locais_de_votacao['sessao']

# %%
column_sessao
# Out:
# 0        Da 87ª à 97ª; 393ª; 410ª; 421ª; 429ª; 438ª; 46...
# 1                          Da 1ª à 27ª; 355ª; 361ª; 529ª;
# 2        509ª; 514ª; 518ª; Da 521ª à 522ª; Da 527ª à 52...
# 3                                          Da 227ª à 251ª.
# 4                             Da 131ª à 139ª; 390ª; 413ª;
